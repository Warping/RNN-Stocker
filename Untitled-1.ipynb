# %%
# !git pull
# Out:
# Already up to date.

# %%
# %run lstm3.py
# Out:
# Sequence Length: 30
# Average Period: 30
# Number of Epochs: 10000
# Hidden Dimension: 500
# Layer Dimension: 2
# Learning Rate: 5e-05
# Training Size: 0.7
# Patience: 100
# Delta: 0.0
# Stock: ^GSPC
# Period: 10y
# Loaded Processed ^GSPC_10y_ data from file
# Normalizing every 30 day period to 30 day average
# Removing last period 2460 to 2486
# Normalizing ^GSPC_10y_data_frame
# Normalizing SMA -- Min: -3.258176122145922, Max: 2.857205688473682
# Normalizing WMA -- Min: -2.8783730852361167, Max: 2.8956661542761206
# Normalizing MOM -- Min: -3.6503370134224005, Max: 3.340712722186596
# Normalizing STCK -- Min: -4.274792849890902, Max: 2.58208940823783
# Normalizing STCD -- Min: -2.727224020917802, Max: 2.815758282983084
# Normalizing RSI -- Min: -3.942592580831956, Max: 3.1116554501632288
# Normalizing MACD -- Min: -2.715853204315712, Max: 2.6044430397724163
# Normalizing LWR -- Min: -2.58208940823783, Max: 4.274792849890901
# ...
