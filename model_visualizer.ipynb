# %%
cd Stock-Analysis/RNN-Stocker/
# Out:
# [Errno 2] No such file or directory: 'Stock-Analysis/RNN-Stocker/'
# /home/jovyan/Stock-Analysis/RNN-Stocker

# %%
# !sudo git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 386 bytes | 386.00 KiB/s, done.
# From https://github.com/Warping/RNN-Stocker
#    47ef343..21fc022  main       -> origin/main
# Updating 47ef343..21fc022
# Fast-forward
#  lstm3.py | 6 ++++--
#  1 file changed, 4 insertions(+), 2 deletions(-)

# %%
# %run lstm3.py --seq_len=30 --avg_period=200 --patience=200
# Out:
# Sequence Length: 30
# Average Period: 200
# Number of Epochs: 10000
# Hidden Dimension: 500
# Layer Dimension: 2
# Learning Rate: 5e-05
# Training Size: 0.7
# Patience: 200
# Delta: 0.0
# Stock: ^GSPC
# Period: 10y
# Loaded Processed ^GSPC_10y_ data from file
# Normalizing every 200 day period to 200 day average
# Removing last period 2400 to 2486
# Normalizing ^GSPC_10y_data_frame
# Normalizing SMA -- Min: -2.693465803900835, Max: 2.3779708856119877
# Normalizing WMA -- Min: -2.902067385763589, Max: 2.290773402218718
# Normalizing MOM -- Min: -3.4551789268790736, Max: 3.2032707041242805
# Normalizing STCK -- Min: -3.468343856122777, Max: 1.6395604184041541
# Normalizing STCD -- Min: -3.2849116826707543, Max: 3.3391224750728807
# Normalizing RSI -- Min: -2.735210620067031, Max: 3.1719631547324703
# Normalizing MACD -- Min: -3.55797353738978, Max: 2.4080467028545014
# Normalizing LWR -- Min: -1.6395604184041541, Max: 3.468343856122777
# ...

# %%
pwd
# Out:
# '/home/jovyan'
