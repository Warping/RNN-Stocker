# %%
cd Stock-Analysis/RNN-Stocker
# Out:
# /home/jovyan/Stock-Analysis/RNN-Stocker

# %%
# !sudo git pull
# Out:
# Already up to date.

# %%
cd LSTM/
# Out:
# /home/jovyan/Stock-Analysis/RNN-Stocker/LSTM

# %%
# %run main.py --stock=VFIAX --period=1y --drop_columns=[SMA,WMA]
# Out:
# CUDA is available. Using GPU.
# Loaded Processed VFIAX_max_ data from file
# Dropping columns: ['SMA', 'WMA']
# Normalizing every 30 day period to 30 day average
# Removing last period 6090 to 6118
# Normalizing VFIAX_max_data_frame
# Normalizing MOM -- Min: -3.3643645945107608, Max: 3.1005739592213137
# Normalizing STCK -- Min: -3.9908489571454697, Max: 3.3994112051924152
# Normalizing STCD -- Min: -2.829254608828339, Max: 3.0529548348252376
# Normalizing RSI -- Min: -3.3489682437139967, Max: 3.382893330256369
# Normalizing MACD -- Min: -3.2182844495852865, Max: 2.749953388228562
# Normalizing LWR -- Min: -3.3994112051924157, Max: 3.99084895714547
# Normalizing CCI -- Min: -3.701659104406143, Max: 3.089954985315385
# Saved Normalized VFIAX_max_ data to file
# Training data shape: torch.Size([4653, 200, 7]), torch.Size([4653, 20, 7])
# Validation data shape: torch.Size([390, 200, 7]), torch.Size([390, 20, 7])
# Test data shape: torch.Size([390, 200, 7]), torch.Size([390, 20, 7])
# ...
