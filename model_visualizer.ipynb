# %%
cd Stock-Analysis/RNN-Stocker
# Out:
# /home/jovyan/Stock-Analysis/RNN-Stocker

# %%
# !sudo git pull
# Out:
# Already up to date.

# %%
cd LSTM/
# Out:
# /home/jovyan/Stock-Analysis/RNN-Stocker/LSTM

# %%
# %run main.py
# Out:
# CUDA is available. Using GPU.
# Loaded Processed IBM_10y_ data from file
# No columns to drop
# Normalizing every 30 day period to 30 day average
# Removing last period 2460 to 2486
# Normalizing IBM_10y_data_frame
# Normalizing SMA -- Min: -2.6726839458479907, Max: 2.8801622654172356
# Normalizing WMA -- Min: -3.208627891675055, Max: 2.548732307671179
# Normalizing MOM -- Min: -3.069830035590379, Max: 3.3467103753701486
# Normalizing STCK -- Min: -3.565224977382853, Max: 3.9654103029136722
# Normalizing STCD -- Min: -3.652062104877179, Max: 2.951405258510452
# Normalizing RSI -- Min: -2.8466900456181103, Max: 2.844791890483725
# Normalizing MACD -- Min: -3.058167028499622, Max: 3.343458906777555
# Normalizing LWR -- Min: -3.96541030291367, Max: 3.565224977382853
# Normalizing CCI -- Min: -2.964036344256501, Max: 3.7875045467064044
# Saved Normalized IBM_10y_ data to file
# Training data shape: torch.Size([1749, 200, 9]), torch.Size([1749, 20, 9])
# ...
