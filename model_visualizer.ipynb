# %%
cd Stock-Analysis/RNN-Stocker/
# Out:
# /home/jovyan/Stock-Analysis/RNN-Stocker

# %%
# !sudo git pull
# Out:
# Already up to date.

# %%
# %run lstm5.py --stock=IBM --period=max --seq_length=200 --prediction_steps=20 --smoothing_window=1 --learning_rate=0.0005 --training_size=0.80 --validation_size=0.1 --test_size=0.1 --hidden_dim=500 --layer_dim=2 --batch_size=4096 --patience=200 --num_epochs=100000
# Out:
# Sequence Length: 200
# Average Period: 30
# Prediction Steps: 20
# Prediction Smoothing: 3
# Number of Epochs: 100000
# Batch Size: 4096
# Hidden Dimension: 500
# Layer Dimension: 2
# Learning Rate: 0.0005
# Training Size: 0.8
# Validation Size: 0.1
# Test Size: 0.1
# Patience: 200
# Delta: 0.0
# Verbose: False
# Stock: IBM
# Drop Columns: []
# Period: max
# Smoothing Window: 1
# Loaded Processed IBM_max_ data from file
# No columns to drop
# Normalizing every 30 day period to 30 day average
# Removing last period 15900 to 15906
# Normalizing IBM_max_data_frame
# Normalizing SMA -- Min: -3.03912617843452, Max: 3.4295860145741286
# Normalizing WMA -- Min: -3.2227602454762905, Max: 3.696466438256211
# Normalizing MOM -- Min: -3.5264158552340525, Max: 3.5559328022110788
# Normalizing STCK -- Min: -5.023054978030897, Max: 3.611810004105085
# Normalizing STCD -- Min: -3.514743960239219, Max: 3.7533281555224494
# Normalizing RSI -- Min: -3.987682455623113, Max: 4.06948824682392
# ...

# %%
pwd
# Out:
# '/home/jovyan/Stock-Analysis/RNN-Stocker'
